# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <a id="imports"></a>
# # Imports
#
# following libraries are used for:
# 1. re - remove unwanted charater from string using regulare expression
# 2. nltk - remove stop words and conjunctions
# 3. numpy - transform data into respective shape
# 4. pandas - import data from file into dataframe
# 5. matplotlib - create visualization
# 6. wordcloud - create word cloud

# %% [markdown]
# # **Resume Screening**

# %%
import re
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

nltk.download("stopwords")

# %% [markdown]
# <a id="read-csv"></a>
# # Read CSV
#
# ID and Resume_html columns does not contain useful information and are not aligend with my interest. Therefore, both columns are removed.

# %%
df = pd.read_csv('/kaggle/input/resume-dataset/Resume/Resume.csv')

df.head()

# %%
# drop unused columns
del df['ID']
del df['Resume_html']
df

# %%
df.rename(columns = {'Resume_str':'Resume'}, inplace = True) 
df

# %% [markdown]
# <a id="preprocessing"></a>
# # Preprocessing
#
# In this stage, I followed basic cleaning processes for text analysis which includes:
# 1. converting characters to lowercases.
# 2. remove punctuations, numbers and foreign languages.
# 3. tokenize word. (spliting sentence into unigram)

# %%
def preprocess(txt):
    # convert all characters in the string to lower case
    txt = txt.lower()
    # remove non-english characters, punctuation and numbers
    txt = re.sub('[^a-zA-Z]', ' ', txt)
    txt = re.sub('http\S+\s*', ' ', txt)  # remove URLs
    txt = re.sub('RT|cc', ' ', txt)  # remove RT and cc
    txt = re.sub('#\S+', '', txt)  # remove hashtags
    txt = re.sub('@\S+', '  ', txt)  # remove mentions
    txt = re.sub('\s+', ' ', txt)  # remove extra whitespace
    # tokenize word
    txt = nltk.tokenize.word_tokenize(txt)
    # remove stop words
    txt = [w for w in txt if not w in nltk.corpus.stopwords.words('english')]
    

    return ' '.join(txt)

# %%
# preprocessing text
df['Resume'] = df['Resume'].apply(lambda w: preprocess(w))

# %%
df

# %% [markdown]
# <a id="exploratory-data-analysis"></a>
# # Exploratory Data Analysis
#
# EDA is excercised to inspect class imbalance, word similarity and word frequency.

# %%
import string
from nltk.corpus import stopwords
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = df['Resume'].values
cleanedSentences = ""
for records in Sentences:
    cleanedSentences += records
    requiredWords = nltk.word_tokenize(records)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)
    
wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)

# %%
wc = WordCloud().generate(cleanedSentences)
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# create list of all categories
categories = np.sort(df['Category'].unique())
categories

# %%
# create new df for corpus and category
df_categories = [df[df['Category'] == category].loc[:, ['Resume', 'Category']] for category in categories]
df_categories

# %% [markdown]
# <a id="barchart"></a>
# ## Bar Chart
#
# The bar chart shows the number of records for each category, where class imbalanced is spotted easily.

# %%
df['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %% [markdown]
# <a id="wordcloud"></a>
# ## Word Cloud
#
# After word clouds are created, the word "manag" (inflected for "manage") prominently visible on many categories. Moreover, words like "citi", "state" and "compani" are noticeable on different categories as well. These common words are likely to contain low weight for computation. On the other hand, words like "account", "develop" and "design" probably has higher weight for calculation because it only appears on specific domains.

# %%
def wordcloud(df):
    txt = ' '.join(txt for txt in df['Resume'])
    wordcloud = WordCloud(
        height=2000,
        width=4000,
        colormap=WORDCLOUD_COLOR_MAP
    ).generate(txt)

    return wordcloud

# %%
WORDCLOUD_COLOR_MAP = 'tab10_r'
plt.figure(figsize=(32, 28))

for i, category in enumerate(categories):
    wc = wordcloud(df_categories[i])

    plt.subplot(5, 5, i + 1).set_title(category)
    plt.imshow(wc)
    plt.axis('off')
    plt.plot()

plt.show()
plt.close()

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder
#
# var_mod = ['Category']
# le = LabelEncoder()
# for i in var_mod:
#     df[i] = le.fit_transform(df[i])<a id="wordfreq"></a>
# ## Word Frequency Table
#
# Word frequency is plotted to visualize how often popular words are used. Most categories have similar distribution on top 10 frequently used words.

# %%
def wordfreq(df):
    count = df['Resume'].str.split(expand=True).stack().value_counts().reset_index()
    count.columns = ['Word', 'Frequency']

    return count.head(10)

# %%
fig = plt.figure(figsize=(32, 64))

for i, category in enumerate(categories):
    wf = wordfreq(df_categories[i])

    fig.add_subplot(5, 5, i + 1).set_title(category)
    plt.bar(wf['Word'], wf['Frequency'])
    plt.ylim(0, 3500)

plt.show()
plt.close()

# %%
from sklearn.preprocessing import LabelEncoder

var_mod = ['Category']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i])

# %%
df

# %%
df.Category.value_counts()

# %%
#Remove Category with a few records (implanced data)
df = df[df.Category != 2]
df = df[df.Category != 5]
df = df[df.Category != 8]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack

requiredText = df['Resume'].values
requiredTarget = df['Category'].values

word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    stop_words='english')
word_vectorizer.fit(requiredText)
WordFeatures = word_vectorizer.transform(requiredText)

print ("Feature completed .....")

# %%
X_train,X_test,y_train,y_test = train_test_split(WordFeatures,requiredTarget,random_state=42, test_size=0.2,
                                                 shuffle=True, stratify=requiredTarget)
print(X_train.shape)
print(X_test.shape)

# %%
clf = OneVsRestClassifier(LogisticRegression(random_state=16))
clf.fit(X_train, y_train)
prediction = clf.predict(X_test)
print('Accuracy of KNeighbors Classifier on training set: {:.2f}'.format(clf.score(X_train, y_train)))
print('Accuracy of KNeighbors Classifier on test set:     {:.2f}'.format(clf.score(X_test, y_test)))

# %%
print("\n Classification report for classifier %s:\n%s\n" % (clf, metrics.classification_report(y_test, prediction)))

# %%
clf1 = OneVsRestClassifier(DecisionTreeClassifier(criterion="entropy", max_depth=3))
clf1.fit(X_train, y_train)
prediction = clf1.predict(X_test)
print('Accuracy of DecisionTreeClassifier on training set: {:.2f}'.format(clf1.score(X_train, y_train)))
print('Accuracy of DecisionTreeClassifier on test set:     {:.2f}'.format(clf1.score(X_test, y_test)))

# %%
print("\n Classification report for classifier %s:\n%s\n" % (clf1, metrics.classification_report(y_test, prediction)))

# %% [markdown]
# # **Resume Parsing**

# %%
# !pip install tika

# %%
from tika import parser

# %%
file = r'/kaggle/input/resume-dataset/data/data/INFORMATION-TECHNOLOGY/10553553.pdf'
file_data = parser.from_file(file)

# %%
text = file_data['content']
#print(text)

# %%
parsed_content = {}

# %%
#E-MAIL
import re
def get_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)

email = get_email_addresses(text)
print(email)
parsed_content['E-mail'] = email

# %%
#PHONE NUMBER
import re
def get_phone_numbers(string):
    r = re.compile(r'(\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4})')
    phone_numbers = r.findall(string)
    return [re.sub(r'\D', '', num) for num in phone_numbers]

phone_number= get_phone_numbers(text)
if len(phone_number) <= 10:
    print(phone_number)
    parsed_content['Phone number'] = phone_number

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

def extract_name(text):
    nlp_text = nlp(text)
    # First name and Last name are always Proper Nouns
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
  
    matcher.add('NAME', [pattern], on_match = None)
  
    matches = matcher(nlp_text)
  
    for match_id, start, end in matches:
        span = nlp_text[start:end]
        return span.text

name = extract_name(text)
print(name)
parsed_content['Name'] =  name

# %%
Keywords = ["education",
            "summary",
            "accomplishments",
            "executive profile",
            "professional profile",
            "personal profile",
            "work background",
            "academic profile",
            "other activities",
            "qualifications",
            "experience",
            "interests",
            "skills",
            "achievements",
            "publications",
            "publication",
            "certifications",
            "workshops",
            "projects",
            "internships",
            "trainings",
            "hobbies",
            "overview",
            "objective",
            "position of responsibility",
            "jobs"
           ]

# %%
text = text.replace("\n"," ")
text = text.replace("[^a-zA-Z0-9]", " ");  
re.sub('\W+','', text)
text = text.lower()
#print(text)

# %%
content = {}
indices = []
keys = []
for key in Keywords:
    try:
        content[key] = text[text.index(key) + len(key):]
        indices.append(text.index(key))
        keys.append(key)
    except:
        pass

# %%
#Sorting the indices
zipped_lists = zip(indices, keys)
sorted_pairs = sorted(zipped_lists)
sorted_pairs

tuples = zip(*sorted_pairs)
indices, keys = [ list(tuple) for tuple in  tuples]
keys

# %%
#Keeping the required content and removing the redundant part
content = []
for idx in range(len(indices)):
    if idx != len(indices)-1:
        content.append(text[indices[idx]: indices[idx+1]])
    else:
        content.append(text[indices[idx]: ])

# %%
for i in range(len(indices)):
    parsed_content[keys[i]] = content[i]

# %%
parsed_content

# %%
pd.DataFrame(parsed_content.items())

# %%
parsed_content['skills']

# %% [markdown]
# <a id="Question & Answering Model"></a>
# # Question & Answering Model

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# !pip3 install -q -U bitsandbytes==0.42.0
# !pip3 install -q -U peft==0.8.2
# !pip3 install -q -U trl==0.7.10
# !pip3 install -q -U accelerate==0.27.1
# !pip3 install -q -U datasets==2.17.0
# !pip3 install -q -U transformers==4.38.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 15.0.2 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.2 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.2.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.2.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.2.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# distributed 2023.7.1 requires dask==2023.7.1, but you have dask 2024.2.0 which is incompatible.
# gcsfs 2023.12.2.post1 requires fsspec==2023.12.2, but you have fsspec 2023.10.0 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.2.0 which is incompatible.
# s3fs 2024.2.0 requires fsspec==2024.2.0, but you have fsspec 2023.10.0 which is incompatible.

# %%
import os
import transformers
import torch
from datasets import load_dataset
from trl import SFTTrainer
from peft import LoraConfig
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig, GemmaTokenizer
from kaggle_secrets import UserSecretsClient
# Out:
# 2024-03-31 09:52:08.209111: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-31 09:52:08.209198: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-31 09:52:08.375089: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
user_secrets = UserSecretsClient()
os.environ["HF_TOKEN"]= user_secrets.get_secret("HF_TOKEN")
#os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

# %%
model_id = "google/gemma-2b"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, token=os.environ['HF_TOKEN'])
model = AutoModelForCausalLM.from_pretrained(model_id,
                                             quantization_config=bnb_config,
                                             device_map={"":0},
                                             token=os.environ['HF_TOKEN'])
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
print (type(tokenizer))
# Out:
# <class 'transformers.models.gemma.tokenization_gemma_fast.GemmaTokenizerFast'>

# %%
text = "Question :What are fields in Information Technology ?"
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens = 150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Question :What are fields in Information Technology ?
#
# Answer :
#
# Fields in Information Technology are the areas of study that deal with the design, development, and implementation of computer systems. They include topics such as computer architecture, software engineering, database management, and networking.
#
# Computer architecture is the study of how computers are designed and built, including topics such as memory, processors, and input/output devices. Software engineering is the study of how to design, develop, and test computer programs, including topics such as algorithms, data structures, and debugging. Database management is the study of how to design, implement, and manage databases, including topics such as relational databases, object-relational databases, and distributed databases. Networking is the study of how to design, implement, and manage computer networks,

# %%
text = "Question : What are fields in Information Technology ?"
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens=150)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Question : What are fields in Information Technology ?
#
# Answer :
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the field of Information Technology.
#
# Fields in Information Technology are the areas of study or specialization in the

# %%
os.environ["WANDB_DISABLED"] = "false"

# %%
lora_config = LoraConfig(
    r = 8,
    target_modules = ["q_proj", "o_proj", "k_proj", "v_proj",
                      "gate_proj", "up_proj", "down_proj"],
    task_type = "CAUSAL_LM",
)

# %%
from datasets import load_dataset
data = load_dataset('csv', data_files = "/kaggle/input/essentiall/Smart Intern Dataset .csv")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# /opt/conda/lib/python3.10/site-packages/datasets/download/streaming_download_manager.py:784: FutureWarning: The 'verbose' keyword in pd.read_csv is deprecated and will be removed in a future version.
#   return pd.read_csv(xopen(filepath_or_buffer, "rb", download_config=download_config), **kwargs)

# %%
data = data.map(lambda samples: tokenizer(samples["Question"]), batched=True)
# Out:
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]

# %%
data['train']['Question']
# Out:
# ['"what are the skills and experience that I should have as Data Networking Intern?"',
#  '"I am an engineering assistant skills  ability to make decisions and solve problems ability to work in a team structure attention to detail balanced computer proficient dependable determined educated fast learner flexible friendly  hardworking honest issue resolution interpersonal skills kind outgoing quick on my feet & with my hands reliable strong verbal communication time management very organized & energetic computer proficient  I want to gain a practical experiences to get a job in this field "',
#  '"As an HR personal assistant with a strong background in administrative support, auditing, and various other skills, gaining further experience in your field can enhance your career prospects and professional development significantly. Here are several strategies to gain experience and elevate your career in HR and administrative support:"',
#  '" I have education bachelor\'s of arts : political science and law, us bachelor\'s of arts degree in political science and law , I want the practical skills and resources  for get a job in my field ."',
#  '"what are the skills and experience that I should have as Recommendation Systems Engineer Intern?"',
#  '"hello I am an intern engineering I have the skills Know-your-consumer (KYC) ,Statistical process control ,Cost reduction andavoidance , Systems Engineering ,Systems Engineering management, Software systems engineering,Quality controlFailure analysis ,Tools of operations research, MS Office and Auto CAD ,I am looking for an opportunity as an engineer or related position which offers key participation, team-oriented tasks, immediate challenges and careeropportunities in a reputed organization which will help me deliver my best and upgrade my skills in engineering and meet the demands of the organization."',
#  '"hello I am an intern engineering I have the skills Know-your-consumer (KYC) ,Statistical process control,Cost reduction and avoidance ,Systems Engineering ,Systems Engineering management ,Software systems engineering ,Quality control ,Failure analysis ,Tools of operations research ,MS Office , Auto CAD and I am looking for an opportunity as an engineer or related position which offers key participation, team-oriented tasks, immediate challenges and careeropportunities in a reputed organization which will help me deliver my best and upgrade my skills in engineering and meet the demands of theorganization."',
#  '"what are the skills and experience that I should have as C++ developer Intern?"',
#  ' "I am information technology technician I have experience in server management, systems analysis, and offering in-depth understanding of it infrastructure areas. detail-oriented, independent, and focused on taking a systematic approach to solving complex problems so I want the skills are simulated workspace experience ."',
#  '" I am an intern accountant and I have skills by drafting over forty memorandums that summarized potential fraud in loans that were presented to multiple agencies of the government. wrote a thirty-five page corporate intelligence narrative explaining personal and professional relationships of an individual under investigation so please tell me about professional  skills and experience that I need to learn it "',
#  '"I am a banking , I am strong team player, attention to detail, compliance in all regulated environment and supervisory skills. skills microsoft word for windows, excel, power point, access, adobe pagemaker 6.5, adobe photoshop, dreamweaver, visio, unix, oracle 9i and developer 2000 , How do I improve my experience for a career in this field?"',
#  '"what are the skills and experience that I should have as Mobile applications Intern?"',
#  '"hi I am in the  sales field I am talent for quickly establishing rapport, cultivating relationships and building loyalty by becoming a trusted customer resource. unparalleled commitment to customer retention by providing superior service. so I need to development my skills in this field"',
#  '"I am a software engineer graduates and I want a career path to obtain a position in the information technology, personnel development, or computer science field to help manage, develop, and support"',
#  '"I am fresh graduates in IT field I want to be Full Stack web developer so I need to learn the skills , requirements with resources and roadmaps with a timeline for step by step in this Job Description: Hidden Logics seeking a full stack developer with 1 year of experience working with the laravel framework.Responsibilities:Develop and maintain web applications using laravel write clean, efficient, and well-documented code collaborate with a team of developers, designers, and project managers to deliver high-quality projects on time stay up-to-date with the latest web development trends and technologies Requirements:1 years of experience working with the laravel framework strong understanding of PHP, HTML, CSS, and JavaScript Experience with git and version control Experience with relational databases (MySQL)"',
#  '"I am an intern business development , I have skills with microsoft word, excel, powerpoint, access and outlook express , maintaining active databases of various hospital proprietary software technology systems so I need to lean more skills and have an experience that i need it in workspace"',
#  '"what are the skills and experience that I should have as Java developer Intern?"',
#  ' "I am a data scientist inter so the job description in company is Experience with web-development with tools like React, Flask, Blazor. We strongly believe that the technology stack is less important than the right know-how on how to learn the dedicated tools in use.Know-how to integrate with databases and architect software in the cloud. Experience how to analyze data with modern data science libraries.We are not limited to any software stack, but we like to program in Javascript/Typescript, Python, C#. Good if you do so too.I need to learn this skills , give me resources , platforms , courses , roadmap to gain this skills with a timeline"',
#  '"I am a designer I have the skills  in building codes knowledge  complex problem solving strong analytical ability excellent attention to detail commercial interior design working drawings and procedures space planning methodology , so I want the skills are simulated workplace experience  The simulations must closely mimic real-life work scenarios, providing authentic experiences that reflect the daily tasks, challenges, and corporate culture of specific companies."',
#  '" I am a digital media graduates ,I have  skills  academic, ads and advertising , I want to explore various career paths and industries through simulated experiences."',
#  '"what are the skills and experience that I should have as Help desk technician Intern?"',
#  '"hello I am an AI engineering intern , I have an experience with python language , ML principles  , optimization algorithms ,I have to get a job so this is a job description :Responsibilities:Development of AI compiler framework, high performance kernel authoring and acceleration onto next generation of hardware architectures. Contribute to the development of the industry-leading machine learning framework core compilers to support new state of the art inference and training machine learning/AI accelerators and optimize their performance. Analyze deep learning networks, develop & implement compiler optimization algorithms. Collaborating with AI research scientists to accelerate the next generation of deep learning models such as recommendation systems, computer vision, or natural language processing. Performance tuning & optimizations of deep learning frameworks. Qualifications: Bachelor’s or Master’s degree in computer science, machine learning, mathematics, physics, electrical engineering or related field. Experience in C/C++, Python, or other related programming languageExperience in accelerating deep learning models or libraries on hardware architectures. Experience working with machine learning frameworks such as PyTorch, TensorFlow, ONNX etc.  Ability to speak and write in English at a business level.so I want to learn this qualifications and skills to qualificat  to this job with an experience so I need to help me to learn and get this skills  and responsibilities "',
#  '"I am a software development ,  my education is master of science , computer engineering  and I want to development my skills focuses on developing job-specific skills and competencies through practical tasks and challenges and  to explore various career paths and industries through simulated experiences.and Incorporates features for networking with professionals and mentors for guidance, simulating the mentorship aspect of real internships."',
#  '"hello I am a software Engineer , this is a job description As a senior backend engineer LLM, you will be part of a cross-functional team, working alongside motivated engineers, applied scientists, product managers, and design specialists on an innovative project to develop a Large Language Model (LLM)-based assistant that will revolutionize how customers shop.Proficient in developing large-scale applications with JVM-based languages (Java, Scala, Kotlin). Scala or Python is a plus.Experience and interest in generative AI & large language models.Experience in the entire software development life cycle: building, testing, deploying, and operating in production. Experience with REST APIs design and event-driven architectures. Stellar communication skills. Entrepreneurial and customer-centric approach.so I want to learn this required  skills so I need a resources , platforms , certain courses , real projects with a timeline for all steps  to learn this qualifications ."',
#  '"I am a Network engineer intern I want to learn this skills in the shortest term with timeline for step by step and real-world projects for every topic  the skills:    CISCO CCNA/CCNP Incidents Level 3, to troubleshoot network problems reported by LVL2. Knowledge of support, run + analytical skills. Knowledge of CISCO ISE + WLC management.  Technical knowledge of Cisco configuration Coordination with other teams (e.g. operator, local IT, project teams)"',
#  '"what are the skills and experience that I should have as IT Technichian Intern?"',
#  ' "I am a pharmacist  , I have a degree of pharmacy so I need to learn my the principles , skills , qualifications , roadmaps , experiences , tasks of marketing in my health care company "',
#  '"Can you suggest companies that offer internships in IT?"',
#  '"Hi , I am fresh graduate in IT field I have some skills in HTML ,CSS , JavaScript and I want to be a web development can you help me please?"',
#  '"I have skills skills  asp.net, vb.net, active directory, ado.net, dreamweaver, web development, agile, ajax, html, ide, java, javascript, jquery, analyst, application development, approach, budget, c, c++, catalogs, charts, css, checkout process, client, clients, data warehouse, database, dcl, eclipse, edit, editor, email, estimating, features, frame, functional, , logic, meetings, access, c#, excel, outlook, power point, windows, window, microsoft word, network, operating system, page, pdf, programmer, programming, progress, quality, qa, research, scheduling, scrum, sdlc, software development, sorting, sql, sql server, tables, tutoring, user interface design, utilities, validation, visual studio, website   and I want to create real projects How can I do that ?"',
#  '"I am a cyber security and I am good in skills for networking issues, end user problems, and network security I want to gain more skills help me for obtain a job in the cyber security field"',
#  '"I am a network engineer and I have experienced in server management, systems analysis, and offering in-depth understanding of it infrastructure areas. detail-oriented, independent, and focused on taking a systematic approach to solving complex problems. demonstrated exceptional technical knowledge so how can i improve my skills ?"',
#  '"what are the skills and experience that I should have as Web Administrator Intern?"',
#  '"I have skills in information technology management and  skills to interface effectively with all levels of an organization. procedure development, quality assurance, troubleshooting, problem solving, process improvement so how can i improve my skills ?"',
#  '"I have education master of science  I need a experience , courses , skills , resources to gain practical experience in workspace how can you help me ?"',
#  '"I am AI engineer so I need courses , resources , with certification in python , machine learning , deep learning and the rest fields in AI "',
#  '"what are the skills and experience that I should have as android Mobile applications Intern?"',
#  '"I am web developer so I want so I need courses , resources , with certification in  fields in Web development"',
#  '"I have studied computer science I am good in programming languages so I need to bridge the gap between academic knowledge and practical workplace skills."',
#  '"I have this skills big data, c, c++, charts, circuit design, hardware, data acquisition, data analyst, data collection, data mining, databases, database and I want to development my skills to get a job"',
#  '"what are the skills and experience that I should have as User Experience Designer Intern?"',
#  '"I am a IT engineer and I know java language and hardware support so I need to  Enhance my Technical Skills"',
#  '"I need to achieve this skills  : Strong  in multiple programming languages, including but not limited to JavaScript, Python, and C++."',
#  '"I want any resources , platforms , websites , courses , real projects to have this qualifications :Hands-On-Experience in code development (e.g. Python, PySpark, SQL, C++, R, Java, Matlab) and usage of Jupyter or Zeppelin Notebooks  ,profound experience with data science, big data analytics and engineering , optional: experience with modern cloud technology and architectures (e.g. AWS)  "',
#  '"what are the skills and experience that I should have as Desktop developer Intern?"',
#  '"I want any resources , platforms , websites , courses , real projects to have this qualifications :  implement, optimize and maintain the backend of new features across all our matching products running on modern technologies (Kotlin on Springboot framework, MongoDB, AWS, Docker) ,write clean, high quality, well-performing code  improve our deployment process by focusing on automations: ,write acceptance tests and implement a robust CI/CD pipeline improve our AWS architecture to make it more sustainable work collaboratively with your fellow full stack engineer Mohit and our Product Team"',
#  '"I want to Being able to understand human-centered processes in the Graphic Arts Industries. , Being able to understand Data Structures, as provided in SQL and XML databases.Being able to program. Having Prolog experience is preferred, but it is not a must.Being able to perform as a team player with good communication skills. Being able to understand German language and English language."',
#  '"what are the skills and experience that I should have as Computer Scientist engineer Intern?"',
#  '"I am an AI engineer so how can i have experience working with RESTful APIs and hands-on expertise with large language models (LLMs) such as GPT-4 ?"',
#  '"this is skills in  a job  :Network Administration and Network Engineering skills , Troubleshooting skills ,Network Security skills , Excellent communication and teamwork skills ,Cisco Certified Network Associate (CCNA) , Cisco Certified Network Professional (CCNP) certification  ,Segment Routing experience is a plus ,Automation/Scripting: Python/ Ansible etc.  ,Experience with Cloud infrastructure and virtualization technologies how can i gain this skills and I need a road map with time line ?"',
#  '"I am a  network systems engineer so how can i have experience working Experience with scalable cloud networks, preferably Azure. Proficiency in Network Security, ideally with FortiGate firewalls. Strong network troubleshooting and analytical skills.Knowledge of cloud platforms, mainly Azure, and DNS system management.,Familiarity with "Infrastructure as Code" tools like Ansible.Experience in Linux/Windows administration, IT security architectures, and IT solution design.Skills in Bash and basic Python scripting. ?"',
#  '"what are the skills and experience that I should have as Game developer Intern?"',
#  '"I am a  network systems engineer so how can i have experience working with Deep understanding of digital electronics, Extensive knowledge of Verilog, System Verilog and UVM ,Experience with standard interfaces, e.g. AMBA-AXI/AHB/APB ,Experience with verification plan creation, coverage definition and closure ,Scripting proficiency in at least one scripting language (e.g. python, perl, bash, tcl) ?"',
#  '"this a job qualifications for Network engineer position :Proven experience as a Network Automation Architect or in a similar role.,Strong knowledge of network protocols, routing, switching, and security.Proficient in scripting and coding languages such as Python, YAML, and Ansible.Experience with network automation tools and frameworks (e.g., Ansible, Puppet, Chef).Familiarity with SDN (Software-Defined Networking) concepts and technologies.Excellent problem-solving and analytical skills. how can i obtain this qualifications ?"',
#  '"what are the skills and experience that I should have as Data base Administrator Intern?"',
#  '"this a job qualifications for Cyber Security position :Demonstrate good knowledge of network security solutions, such as firewalls, routers, and switches .Basic understanding of various information system technologies (i.e., TCP/IP, IPsec, IPS, Windows/Linux systems, Active Directory, VMWare) .Entry level network engineering qualifications (CCNA, CompTIA Network+) will be considered an advantage ,Hands-on experience with network management and monitoring tools ?"',
#  '"this a job qualifications for Cyber Security engineer position :xperience with Java or C# /.NET or C++, and Python.Scripting abilities with Unix command line (curl, grep, awk, sed, chmod, ssh, etc) , Experience with web programming and technologies.Experience with CI/CD system components such as Jenkins, Concourse, Bamboo, Circle.Prefer candidates with a deep knowledge of software security and architectures.Cloud programming / Azure DevOps would be a plus.?"',
#  '"this a job qualifications for Cyber Securit engineer so how can i have experience working Experience with Access Management , Knowledge of ITIL framework processes , Sound Knowledge of Active Directory, Experience with Role Based Access Controls , Understanding of Windows security modelExperience with Sailpoint, Azman, Knowledge of AWS Identity and Access Management (IAM), Azure Access Management , Unix Shell / Bash , PowerShell , SQl/PLSQL the question is how can i get it ?"',
#  '"what are the skills and experience that I should have as Database Management Intern?"',
#  '"this a job qualifications for Cyber Security engineer position :Experience with coding/scripting in one or more languages (Python, C, C++, Java) Experience with Linux operating systems (Ubuntu preferred) Understanding of concepts related to Systems Engineering/DevOps, IaC, IAM, network security, systems security, cryptography Have a wide understanding of cybersecurity and data protection frameworks such as ISO 27001, NIST, SOC2, PCI-DSS, GDPR, CCPA. the question is how can i get this experience and skills ?"',
#  '"Can you suggest any courses or resources , platforms , websites , real projects  I can learn fields :Data Science, Statistics, and Data Analytics skills , Data Visualization and Data Analysis skills , Experience in working with Oracle, Microsoft, SAS, or Jedox platforms ,Proficiency in programming languages such as Python, R, or SQL?"',
#  'Can you suggest any courses or resources , platforms , websites , real projects  I can gain this experience and knowledge : Collaborate with cross-functional teams to develop, deploy, and maintain AI-driven solutions. Assist in collecting, cleaning, and analyzing data from various sources to derive actionable insights.Contribute to the design and implementation of scalable data pipelines for model training and deployment. Support the integration of machine learning models into production systems using DevOps best practices. Participate in designing and optimizing CI/CD pipelines for continuous integration, testing, and deployment of AI applications on cloud platforms. Assist in infrastructure provisioning, configuration, and monitoring using cloud services such as AWS, Azure, or Google Cloud.Work closely with data scientists and engineers to understand business requirements and translate them into technical solutions. Research and experiment with emerging technologies and tools in AI, Data Science, DevOps, and Cloud domains.?',
#  '"what are the skills and experience that I should have as Artificial Intelligence Intern?"',
#  '"this a job qualifications for Data Base Management position :Proficient with MS Office programs (i.e. Excel, Word) ,Knowledge of ERP and PDM (QAD/Team Center ) ?"',
#  '"what are the skills and experience that I should have as Data Engineer Intern?"',
#  '"Can you suggest any courses or resources , platforms , websites , real projects  I can gain this experience and knowledge : Good knowledge of Oracle 12; Good knowledge of PL/SQL and MySQL Oracle?"',
#  '"what are the skills and experience that I should have as NLP Intern?"',
#  '"what are the skills and experience that I should have as Software Engineering Intern?"',
#  '"what are the skills and experience that I should have as Designer Intern?"',
#  '"what are the skills and experience that I should have as IT infrastructure Engineer Intern?"',
#  '"what are the skills and experience that I should have as Network Engineer Intern?"',
#  '"what are the skills and experience that I should have as Computer Vision Intern?"',
#  '"what are the skills and experience that I should have as Web developer Intern?"',
#  '"what are the skills and experience that I should have as System Management Intern?"',
#  '"what are the skills and experience that I should have as Data Analyst Intern?"',
#  '"what are the skills and experience that I should have as Web design Intern?"',
#  '"what are the skills and experience that I should have as Cloud computing engineer Intern?"',
#  '"what are the skills and experience that I should have as Cyber Security Intern?"',
#  '"what are the skills and experience that I should have as Information Security Intern?"',
#  '"what are the skills and experience that I should have as Information Technology Intern?"',
#  '"what are the skills and experience that I should have as Data Scientist Intern?"',
#  '"what are the skills and experience that I should have as Machine Learning Engineer Intern?"',
#  '"what are the skills and experience that I should have as Computer support Intern?"',
#  '"what are the skills and experience that I should have as Python developer Intern?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn C++ language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Java language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn python language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Javascript language?"',
#  '"give me any resources , videos , courses , platforms , websites to learn C# language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn C language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn php language?"',
#  '"give me any resources , videos , courses , platforms , websites to learn R language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Kotlin language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Go language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn SQL language?"',
#  '"give me any resources , videos , courses , platforms , websites to learn Rust language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn HTML language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Ruby language?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn CSS ?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn VB.NET language?"',
#  '"give me any resources , videos , courses , platforms , websites to learn Assembly language ?"',
#  '"give me any resources , videos , courses , platforms , websites to learn Swift?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn MATLAB language ?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn Visual Basic .NET language ?"',
#  '"give me any resources , videos , courses , platforms , websites to  learn prolog language ?"',
#  '"How can i learn Laravel framework give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"How can i become a strong problems solver ?"',
#  '"I want a roadmap , timeline to l earn UI & UX  give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn Tensorflow framework  give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn pytorch framework  give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn sikitlearn framework  give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn power bi give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn tableau framework  give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I want a roadmap , timeline to l earn using Github give me any resources , videos , courses , platforms , websites ,books  ?"',
#  '"I don\'t know any thing about video editing so  How can i working in this field ?"',
#  '"I don\'t know any thing about AI  so  How can i working in this field ?"',
#  '"I don\'t know any thing about Back-end  so  How can i working in this field ?"',
#  '"I don\'t know any thing about front-end  so  How can i working in this field ?"',
#  '"I don\'t know any thing about Flutter  so  How can i working in this field ?"',
#  '"I don\'t know any thing about Full stack web developer so  How can i working in this field ?"',
#  '"I don\'t know any thing about Django framework so  How can i working in this field ?"',
#  '"I don\'t know any thing about SEO so How can i working in this field ?"',
#  '"I don\'t know any thing about Angular framework so  How can i working in this field ?"',
#  '"I don\'t know any thing about Wordpress so  How can i working in this field ?"',
#  '"I don\'t know any thing about ReactJS ,so How can i working in this field ?"',
#  '"I don\'t know any thing about Node.js so How can i working in this field ?"',
#  '"I don\'t know any thing about Graphics designer ,so  How can i working in this field ?"',
#  '"I don\'t know any thing about product designer so  How can i working in this field ?"',
#  '"I don\'t know any thing about NextJs ,so  How can i working in this field ?"',
#  '"I don\'t know any thing about Web application so  How can i working in this field ?"',
#  '"I don\'t know any thing about IOS development  ,so  How can i working in this field ?"',
#  '"I don\'t know any thing about Motion Graphic Designer ,so How can i working in this field ?"',
#  '"How have i the Strong skills solving Data Structures and Algorithms problems?"',
#  '"How have i the Strong skills as  Robotics Software Engineer intern ?"',
#  '"I don\'t know any thing about System Analyst ,so  How can i working in this field ?"',
#  'I want to have an Experience in NodeJS/NestJS  , High proficiency with ExpressJS and Typescript. ,Experience in designing database architecture, and familiarity with databases (e.g. MongoDB). ,Experience in designing and developing RESTful API ,Experience integrating third-party services , Experience in Git., how do that tell me with examples, courses , books , platforms , timeline , roadmap ?',
#  '"How to be Technical Support Specialist pleas help me to learn it ?"',
#  'I want to have an experience in Laravel, Vue, and TailwindCSS development ,Experience in Git., how do that tell me with examples, courses , books , platforms , timeline , roadmap ?',
#  '"I want to have an experience in - Typescript , HTML5, CSS3, JavaScript/ES6+ , libraries like RTK, and Rtk Query, how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in - Php Laravel , Vue js ,inertia ,Html ,Css ,Bootstrap ,Git how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in - Photoshop  ,Illustrator , InDesign  , how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in -Experience in building ERP systems , relational databases (e.g., MySQL) and database design.  how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  'I want to have an experience in -Experience in building XP in Swift/Objective-C , strong OOP knowledge.  how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in - Database Administration (Oracle, SQL Server and My SQL)  , Development Professional / Operating Systems Professional Certificates (UNIX) / ITIL , how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in -  Javascript, Jquery ,  Bootstrap 4 & 5 ,Database SQL, ASP.NET (Added Value) , how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in   JavaScript, including DOM manipulation and the JavaScript object model. ,  React.js and its core principles, including React hooks,  newer specifications of EcmaScript , data structure libraries (e.g., Immutable.js) , isomorphic React  , front-end development tools such as Babel, Webpack, NPM, etc , code versioning tools, such as Git..  how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in -Generative AI , how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"',
#  '"I want to have an experience in   languages such as Python, Java, or C++ ,  Solid understanding of machine learning algorithms, statistical modelling, and data analysis , Experience with popular machine learning frameworks (e.g., TensorFlow, PyTorch) , Proficiency in working with large datasets and databases , Familiarity with cloud platforms and AI services (e.g., AWS, Azure, Google Cloud).  how do that tell me with examples, courses , books , platforms , timeline , roadmap ?"']

# %%
def formatting_func(example):
    text = f"Question: {example['Question'][0]}\nAnswer: {example['Answer'][0]}"
    return [text]

# %%
data['train']
# Out:
# Dataset({
#     features: ['Question', 'Answer', 'input_ids', 'attention_mask'],
#     num_rows: 148
# })

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=data["train"],
    args=transformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=100,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir="outputs",
        optim="paged_adamw_8bit"
    ),
    peft_config=lora_config,
    formatting_func=formatting_func,
)
# Out:
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:223: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/148 [00:00<?, ? examples/s]
# /opt/conda/lib/python3.10/site-packages/trl/trainer/sft_trainer.py:290: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(

# %%
trainer.train()#c1b73ca72fb3109769dc38673f0fd2f05fd2e87c
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ·····························································
# wandb: ERROR API key must be 40 characters long, yours was 61
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.16.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240331_095404-lv6os2on</code>
# Syncing run <strong><a href='https://wandb.ai/nournirabi/huggingface/runs/lv6os2on' target="_blank">gallant-disco-8</a></strong> to <a href='https://wandb.ai/nournirabi/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nournirabi/huggingface' target="_blank">https://wandb.ai/nournirabi/huggingface</a>
#  View run at <a href='https://wandb.ai/nournirabi/huggingface/runs/lv6os2on' target="_blank">https://wandb.ai/nournirabi/huggingface/runs/lv6os2on</a>
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 06:09, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.442700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.425900</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.406600</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.385200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.362400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.338000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.312500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.286900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.261100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.236200</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.211200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.186400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.161800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.137600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.114200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.093700</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.075700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.059800</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.046400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.036300</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.029700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.016400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.013500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.006500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.000900</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.000700</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.000600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.000300</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.05637011506391586, metrics={'train_runtime': 453.4761, 'train_samples_per_second': 1.764, 'train_steps_per_second': 0.221, 'total_flos': 914185820160000.0, 'train_loss': 0.05637011506391586, 'epoch': 100.0})

# %%
text = "Question : I'm Lina, and I've just finished my studies in marketing. Despite my degree, I feel unprepared for the digital aspects of marketing, which seem to dominate job listings. I need to gain practical experience in digital marketing strategies and tools. Does Smart Intern offer simulations that can help me build these skills and receive evaluations on my performance?"
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = model.generate(**inputs, max_new_tokens = 600)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Question : I'm Lina, and I've just finished my studies in marketing. Despite my degree, I feel unprepared for the digital aspects of marketing, which seem to dominate job listings. I need to gain practical experience in digital marketing strategies and tools. Does Smart Intern offer simulations that can help me build these skills and receive evaluations on my performance?
#
# Answer : Smart Intern provides a unique opportunity to gain hands-on experience in digital marketing through interactive simulations that simulate the processes and strategies of digital marketing. By engaging with these simulations, you can learn essential skills such as keyword research, link building, social media marketing, email marketing, and advertising campaigns, without needing to invest time or money in actual projects. The simulations provide a hands-on experience that can prepare you well for actual projects and interviews by giving you a clear understanding of the strategies and tools that you should be familiar with as a marketing professional. Here's a guide to the types of simulations that Smart Intern offers and how to make the most of them:
#
# Simulations for Search Engine Optimization (SEO): These simulations can help you learn how to optimize your website for search engines by implementing strategies such as keyword research, content creation, link building, and meta tag optimization. Many of Smart Intern's SEO simulations allow you to interact with the search engine results page (SERP) and see how your changes affect your ranking. This hands-on experience can prepare you well for actual SEO projects by giving you a clear understanding of the factors that influence search engine rankings and how to optimize your website for them.
#
# Simulations for Social Media Marketing: Social media marketing involves promoting your brand and products through platforms such as Facebook, Instagram, and Twitter. Smart Intern's social media simulations can help you learn how to create effective social media campaigns by planning content interspersions, scheduling posts, and monitoring engagement. By interacting with the platforms directly through the simulations, you can gain a deeper understanding of the platforms' features, algorithms, and metrics that should guide your social media marketing efforts.
#
# Simulations for Email Marketing: Email marketing involves sending marketing messages to a list of subscribers. Smart Intern's email marketing simulations can help you learn how to design and send effective email campaigns by crafting subject lines, body texts, and calls to action, and scheduling and sending emails at the right time. By interacting with the emails in the simulations, you can see how they appear in the recipient's inbox and how they perform in terms of open rates, click rates, and engagement.
#
# Simulations for Advertising: Digital advertising involves investing in advertising campaigns to drive traffic to your website or products through platforms such as Google Ads, Facebook Ads, and Instagram Ads. Smart Intern's advertising simulations can provide a hands-on experience by letting you create and manage advertising campaigns while seeing their performance in terms of

# %%
import cloudpickle
cloudpickle.dump(model, open('model.pkl', 'wb'))

# %%
pickled_model = cloudpickle.load(open('/kaggle/working/model.pkl', 'rb'))

# %%
text = "Question : I'm Lina, and I've just finished my studies in marketing. Despite my degree, I feel unprepared for the digital aspects of marketing, which seem to dominate job listings. I need to gain practical experience in digital marketing strategies and tools. Does Smart Intern offer simulations that can help me build these skills and receive evaluations on my performance?"
device = "cuda:0"
inputs = tokenizer(text, return_tensors="pt").to(device)

outputs = pickled_model.generate(**inputs, max_new_tokens = 500)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Question : I'm Lina, and I've just finished my studies in marketing. Despite my degree, I feel unprepared for the digital aspects of marketing, which seem to dominate job listings. I need to gain practical experience in digital marketing strategies and tools. Does Smart Intern offer simulations that can help me build these skills and receive evaluations on my performance?
#
# Answer : Smart Intern provides a unique opportunity to gain hands-on experience in digital marketing through interactive simulations that simulate the processes and strategies of digital marketing. By engaging with these simulations, you can learn essential skills such as keyword research, link building, social media marketing, email marketing, and advertising campaigns, without needing to invest time or money in actual projects. The simulations provide a hands-on experience that can prepare you well for actual projects and interviews by giving you a clear understanding of the strategies and tools that you should be familiar with as a marketing professional. Here's a guide to the types of simulations that Smart Intern offers and how to make the most of them:
#
# Simulations for Search Engine Optimization (SEO): These simulations can help you learn how to optimize your website for search engines by implementing strategies such as keyword research, content creation, link building, and meta tag optimization. Many of Smart Intern's SEO simulations allow you to interact with the search engine results page (SERP) and see how your changes affect your ranking. This hands-on experience can prepare you well for actual SEO projects by giving you a clear understanding of the factors that influence search engine rankings and how to optimize your website for them.
#
# Simulations for Social Media Marketing: Social media marketing involves promoting your brand and products through platforms such as Facebook, Instagram, and Twitter. Smart Intern's social media simulations can help you learn how to create effective social media campaigns by planning content interspersions, scheduling posts, and monitoring engagement. By interacting with the platforms directly through the simulations, you can gain a deeper understanding of the platforms' features, algorithms, and metrics that should guide your social media marketing efforts.
#
# Simulations for Email Marketing: Email marketing involves sending marketing messages to a list of subscribers. Smart Intern's email marketing simulations can help you learn how to design and send effective email campaigns by crafting subject lines, body texts, and calls to action, and scheduling and sending emails at the right time. By interacting with the emails in the simulations, you can see how they appear in the recipient's inbox and how they perform in terms of open rates, click rates, and engagement.
#
# Simulations for Advertising: Digital advertising involves investing in advertising campaigns to drive traffic to your website or products through platforms such as Google Ads, Facebook Ads, and Instagram Ads. Smart Intern's advertising simulations can provide a hands-on experience by letting you create and manage advertising campaigns while seeing their performance in terms of

# %%
import zipfile
import os

# Specify the file you want to compress
file_to_compress = "/kaggle/working/model2.pkl"
# Specify the output ZIP file name
zip_filename = "/kaggle/working/model2.zip"

# Create a ZIP file and add your file
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(file_to_compress, arcname=os.path.basename(file_to_compress))

print(f"File compressed and saved as {zip_filename}")

# %%
import gzip
import shutil

# Specify the file you want to compress
file_to_compress = "/kaggle/working/model2.pkl"
# Specify the output GZ file name
gz_filename = "/kaggle/working/model2.pkl.gz"

# Compress the file
with open(file_to_compress, 'rb') as f_in:
    with gzip.open(gz_filename, 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

print(f"File compressed and saved as {gz_filename}")

# %% [markdown]
# <a id="Deployment Model with Streamlit"></a>
# # Deployment Model with Streamlit

# %%
# !pip install streamlit

# %%
import streamlit as st

# %%
def SmartIntern_prediction(input_text) :
    device = "cuda:0"
    
    inputs = tokenizer(input_text, return_tensors="pt").to(device)
    
    outputs = pickled_model.generate(**inputs, max_new_tokens = 500)
    
    return(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
def main():
    
    st.title("Smart Intern")
    st.header("How can i help you !")
    input_text = st.text_input('text input')
    output = SmartIntern_prediction(input_text)
    st.success(output)

# %%
if __name__ == '__main__':
    
    main()

# %%
st run main
